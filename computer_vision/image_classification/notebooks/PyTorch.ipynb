# %% [markdown]
# <a href="https://colab.research.google.com/github/AIEngineerOnDemand/PyTorch-Use-Cases/blob/master/computer_vision/image_classification/PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
# !git clone https://github.com/AIEngineerOnDemand/PyTorch-Use-Cases.git
# Out:
# Cloning into 'PyTorch-Use-Cases'...
# remote: Enumerating objects: 294, done.
# remote: Counting objects: 100% (294/294), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 294 (delta 134), reused 267 (delta 112), pack-reused 0
# Receiving objects: 100% (294/294), 220.35 KiB | 7.11 MiB/s, done.
# Resolving deltas: 100% (134/134), done.

# %%
# %cd PyTorch-Use-Cases/
# !pip install poetry
# !poetry install
# Out:
# /content/PyTorch-Use-Cases
# Collecting poetry
#   Downloading poetry-1.8.3-py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: build<2.0.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from poetry) (1.2.1)
# Requirement already satisfied: cachecontrol[filecache]<0.15.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (0.14.0)
# Collecting cleo<3.0.0,>=2.1.0 (from poetry)
#   Downloading cleo-2.1.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.6 MB/s eta 0:00:00
# Collecting crashtest<0.5.0,>=0.4.1 (from poetry)
#   Downloading crashtest-0.4.1-py3-none-any.whl (7.6 kB)
# Collecting dulwich<0.22.0,>=0.21.2 (from poetry)
#   Downloading dulwich-0.21.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (514 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (2.19.1)
# Collecting installer<0.8.0,>=0.7.0 (from poetry)
#   Downloading installer-0.7.0-py3-none-any.whl (453 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 34.7 MB/s eta 0:00:00
# Collecting keyring<25.0.0,>=24.0.0 (from poetry)
#   Downloading keyring-24.3.1-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from poetry) (24.1)
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (4.9.0)
# Collecting pkginfo<2.0,>=1.10 (from poetry)
#   Downloading pkginfo-1.11.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs<5,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (4.2.2)
# Collecting poetry-core==1.9.0 (from poetry)
#   Downloading poetry_core-1.9.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 31.2 MB/s eta 0:00:00
# Collecting poetry-plugin-export<2.0.0,>=1.6.0 (from poetry)
#   Downloading poetry_plugin_export-1.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyproject-hooks<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (1.1.0)
# Requirement already satisfied: requests<3.0,>=2.26 in /usr/local/lib/python3.10/dist-packages (from poetry) (2.31.0)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from poetry)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: shellingham<2.0,>=1.5 in /usr/local/lib/python3.10/dist-packages (from poetry) (1.5.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from poetry) (2.0.1)
# Collecting tomlkit<1.0.0,>=0.11.4 (from poetry)
#   Downloading tomlkit-0.12.5-py3-none-any.whl (37 kB)
# Collecting trove-classifiers>=2022.5.19 (from poetry)
#   Downloading trove_classifiers-2024.5.22-py3-none-any.whl (13 kB)
# Collecting virtualenv<21.0.0,>=20.23.0 (from poetry)
#   Downloading virtualenv-20.26.2-py3-none-any.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 57.0 MB/s eta 0:00:00
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (1.0.8)
# Requirement already satisfied: filelock>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (3.14.0)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from cleo<3.0.0,>=2.1.0->poetry)
#   Downloading rapidfuzz-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 45.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from dulwich<0.22.0,>=0.21.2->poetry) (2.0.7)
# Collecting jaraco.classes (from keyring<25.0.0,>=24.0.0->poetry)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.10/dist-packages (from keyring<25.0.0,>=24.0.0->poetry) (7.1.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect<5.0.0,>=4.7.0->poetry) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry) (2024.6.2)
# Collecting distlib<1,>=0.3.7 (from virtualenv<21.0.0,>=20.23.0->poetry)
#   Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 34.2 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.0.0->poetry) (3.19.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from jaraco.classes->keyring<25.0.0,>=24.0.0->poetry) (10.1.0)
# Installing collected packages: trove-classifiers, distlib, virtualenv, tomlkit, rapidfuzz, poetry-core, pkginfo, jaraco.classes, installer, dulwich, crashtest, requests-toolbelt, keyring, cleo, poetry-plugin-export, poetry
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
# Successfully installed cleo-2.1.0 crashtest-0.4.1 distlib-0.3.8 dulwich-0.21.7 installer-0.7.0 jaraco.classes-3.4.0 keyring-24.3.1 pkginfo-1.11.1 poetry-1.8.3 poetry-core-1.9.0 poetry-plugin-export-1.8.0 rapidfuzz-3.9.3 requests-toolbelt-1.0.0 tomlkit-0.12.5 trove-classifiers-2024.5.22 virtualenv-20.26.2
# Creating virtualenv pytorch-use-cases-j0xkPS9M-py3.10 in /root/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
#
# Package operations: 52 installs, 0 updates, 0 removals
#
#   - Installing nvidia-nvjitlink-cu12 (12.5.40): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.5.40): Downloading... 0%
#   - Installing nvidia-nvjitlink-cu12 (12.5.40): Downloading... 10%
#   - Installing nvidia-nvjitlink-cu12 (12.5.40): Downloading... 40%
#   - Installing nvidia-nvjitlink-cu12 (12.5.40): Downloading... 70%
#   - Installing nvidia-nvjitlink-cu12 (12.5.40): Downloading... 100%
#   - Installing nvidia-nvjitlink-cu12 (12.5.40): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.5.40)
#   - Installing filelock (3.15.1): Pending...
#   - Installing markupsafe (2.1.5): Pending...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing markupsafe (2.1.5): Downloading... 0%
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing markupsafe (2.1.5): Downloading... 100%
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing markupsafe (2.1.5): Installing...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing filelock (3.15.1): Downloading... 0%
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Pending...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing mpmath (1.3.0): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing filelock (3.15.1): Downloading... 100%
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing filelock (3.15.1): Installing...
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing filelock (3.15.1)
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Downloading... 0%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing mpmath (1.3.0): Downloading... 10%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing mpmath (1.3.0): Downloading... 50%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing mpmath (1.3.0): Downloading... 100%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing mpmath (1.3.0): Installing...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing mpmath (1.3.0)
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 0%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 10%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 20%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 20%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 4%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 20%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 30%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 30%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 10%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 30%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 40%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 40%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 17%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 40%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 50%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 50%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 20%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 50%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 60%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 60%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 27%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 60%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 70%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 70%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 30%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 70%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 80%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 80%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 36%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 80%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 90%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 90%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 40%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 90%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 90%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 46%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 90%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 90%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 50%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 90%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 100%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 100%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 60%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 100%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 100%
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 70%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Downloading... 100%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
# Installing /root/.cache/pypoetry/virtualenvs/pytorch-use-cases-j0xkPS9M-py3.10/lib/python3.10/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 80%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 90%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 97%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Downloading... 100%
#   - Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106)
#   - Installing nvidia-cusparse-cu12 (12.1.0.106)
#   - Installing nvidia-cublas-cu12 (12.1.3.1): Installing...
#   - Installing nvidia-cusparse-cu12 (12.1.0.106)
# Installing /root/.cache/pypoetry/virtualenvs/pytorch-use-cases-j0xkPS9M-py3.10/lib/python3.10/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-cusparse-cu12 (12.1.0.106)
#   - Installing nvidia-cublas-cu12 (12.1.3.1)
#   - Installing nvidia-cusparse-cu12 (12.1.0.106)
#   - Installing certifi (2024.6.2): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing certifi (2024.6.2): Downloading... 0%
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing idna (3.7): Downloading... 0%
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing idna (3.7): Downloading... 0%
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing fsspec (2024.6.0): Downloading... 0%
#   - Installing idna (3.7): Downloading... 0%
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Downloading... 0%
#   - Installing idna (3.7): Downloading... 0%
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing certifi (2024.6.2): Downloading... 100%
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Downloading... 0%
#   - Installing idna (3.7): Downloading... 0%
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing idna (3.7): Downloading... 100%
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing idna (3.7): Installing...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing idna (3.7): Installing...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing fsspec (2024.6.0): Downloading... 100%
#   - Installing idna (3.7): Installing...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Downloading... 100%
#   - Installing idna (3.7): Installing...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing certifi (2024.6.2): Installing...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Downloading... 100%
#   - Installing idna (3.7): Installing...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing idna (3.7): Installing...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7): Installing...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing numpy (2.0.0): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing numpy (2.0.0): Pending...
#   - Installing certifi (2024.6.2)
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Pending...
#   - Installing numpy (2.0.0): Pending...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   - Installing numpy (2.0.0): Pending...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   - Installing networkx (3.2.1): Downloading... 0%
#   - Installing numpy (2.0.0): Pending...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 0%
#   - Installing numpy (2.0.0): Pending...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing charset-normalizer (3.3.2): Downloading... 0%
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 0%
#   - Installing numpy (2.0.0): Pending...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing charset-normalizer (3.3.2): Downloading... 100%
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing networkx (3.2.1): Downloading... 50%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 50%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing charset-normalizer (3.3.2): Installing...
#   - Installing fsspec (2024.6.0): Installing...
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 50%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 50%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing fsspec (2024.6.0)
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 50%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing fsspec (2024.6.0)
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 50%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing charset-normalizer (3.3.2)
#   - Installing fsspec (2024.6.0)
#   - Installing idna (3.7)
#   - Installing jinja2 (3.1.4): Pending...
#   - Installing networkx (3.2.1): Downloading... 50%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   - Installing networkx (3.2.1): Downloading... 100%
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 0%
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 0%
#   - Installing jinja2 (3.1.4): Downloading... 0%
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 100%
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 100%
#   - Installing jinja2 (3.1.4): Downloading... 70%
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 100%
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 100%
#   - Installing jinja2 (3.1.4): Downloading... 100%
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing jinja2 (3.1.4): Installing...
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
# Installing /root/.cache/pypoetry/virtualenvs/pytorch-use-cases-j0xkPS9M-py3.10/lib/python3.10/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing numpy (2.0.0): Downloading... 10%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 10%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing jinja2 (3.1.4)
#   - Installing networkx (3.2.1): Installing...
#   - Installing numpy (2.0.0): Downloading... 10%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 10%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 20%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 50%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 50%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 30%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 50%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 20%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 60%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 70%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 70%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 40%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 70%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 30%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 80%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 80%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 50%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 80%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 40%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 50%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 50%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 60%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 50%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 60%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 60%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 70%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 60%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 60%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 60%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 70%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 7%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 70%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 7%
#   - Installing numpy (2.0.0): Downloading... 80%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 70%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 7%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 70%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 7%
#   - Installing numpy (2.0.0): Downloading... 90%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 70%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 7%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 7%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 80%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 7%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing numpy (2.0.0): Downloading... 90%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 80%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing networkx (3.2.1)
#   - Installing numpy (2.0.0): Downloading... 90%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 80%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Pending...
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Pending...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Pending...
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Installing...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 1%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 0%
# Installing /root/.cache/pypoetry/virtualenvs/pytorch-use-cases-j0xkPS9M-py3.10/lib/python3.10/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 0%
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 2%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 0%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Installing...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 2%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 0%
#   - Installing numpy (2.0.0): Downloading... 100%
#   - Installing nvidia-cuda-cupti-cu12 (12.1.105): Installing...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 90%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 2%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 0%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   - Installing nvidia-cudnn-cu12 (8.9.2.26): Downloading... 2%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Downloading... 0%
#   - Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Downloading... 100%
#   - Installing nvidia-cuda-runtime-cu12 (12.1.105)
# ...
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing safetensors (0.4.3): Pending...
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing joblib (1.4.2): Installing...
#   - Installing matplotlib (3.9.0): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing safetensors (0.4.3): Pending...
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing huggingface-hub (0.23.4): Installing...
#   - Installing joblib (1.4.2): Installing...
#   - Installing matplotlib (3.9.0): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing safetensors (0.4.3): Pending...
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing safetensors (0.4.3): Pending...
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 10%
#   - Installing safetensors (0.4.3): Pending...
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing safetensors (0.4.3): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 10%
#   - Installing safetensors (0.4.3): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing matplotlib (3.9.0): Downloading... 20%
#   - Installing pandas (2.2.2): Downloading... 10%
#   - Installing safetensors (0.4.3): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing safetensors (0.4.3): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 20%
#   - Installing safetensors (0.4.3): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing safetensors (0.4.3): Downloading... 100%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 20%
#   - Installing safetensors (0.4.3): Downloading... 100%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing matplotlib (3.9.0): Downloading... 40%
#   - Installing pandas (2.2.2): Downloading... 20%
#   - Installing safetensors (0.4.3): Downloading... 100%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 30%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 0%
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing pandas (2.2.2): Downloading... 30%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing matplotlib (3.9.0): Downloading... 60%
#   - Installing pandas (2.2.2): Downloading... 30%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing matplotlib (3.9.0): Downloading... 60%
#   - Installing pandas (2.2.2): Downloading... 30%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing joblib (1.4.2)
#   - Installing matplotlib (3.9.0): Downloading... 60%
#   - Installing pandas (2.2.2): Downloading... 30%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0): Pending...
#   - Installing joblib (1.4.2)
#   - Installing matplotlib (3.9.0): Downloading... 60%
#   - Installing pandas (2.2.2): Downloading... 30%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0): Pending...
#   - Installing huggingface-hub (0.23.4)
#   - Installing joblib (1.4.2)
#   - Installing matplotlib (3.9.0): Downloading... 60%
#   - Installing pandas (2.2.2): Downloading... 30%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0): Pending...
#   - Installing torchvision (0.17.2): Pending...
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0): Pending...
#   - Installing torchvision (0.17.2): Pending...
#   - Installing pandas (2.2.2): Downloading... 40%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0): Pending...
#   - Installing torchvision (0.17.2): Pending...
#   - Installing torchvision (0.17.2): Pending...
#   - Installing threadpoolctl (3.5.0): Downloading... 0%
#   - Installing torchvision (0.17.2): Pending...
#   - Installing torchvision (0.17.2): Pending...
#   - Installing threadpoolctl (3.5.0): Downloading... 100%
#   - Installing torchvision (0.17.2): Pending...
#   - Installing torchvision (0.17.2): Pending...
#   - Installing threadpoolctl (3.5.0): Installing...
#   - Installing torchvision (0.17.2): Pending...
#   - Installing torchvision (0.17.2): Downloading... 0%
#   - Installing torchvision (0.17.2): Downloading... 0%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 40%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 0%
#   - Installing matplotlib (3.9.0): Downloading... 80%
#   - Installing pandas (2.2.2): Downloading... 40%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 0%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 50%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 0%
#   - Installing torchvision (0.17.2): Downloading... 20%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 20%
#   - Installing pandas (2.2.2): Downloading... 60%
#   - Installing safetensors (0.4.3): Installing...
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 20%
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 20%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 10%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 20%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 20%
#   - Installing scipy (1.13.1): Downloading... 20%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 20%
#   - Installing torchvision (0.17.2): Downloading... 30%
#   - Installing pandas (2.2.2): Downloading... 60%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 20%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 30%
#   - Installing matplotlib (3.9.0): Downloading... 100%
#   - Installing pandas (2.2.2): Downloading... 60%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 20%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 30%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 20%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 30%
#   - Installing pandas (2.2.2): Downloading... 70%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 20%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 30%
#   - Installing torchvision (0.17.2): Downloading... 50%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 20%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 50%
#   - Installing pandas (2.2.2): Downloading... 80%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 20%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 50%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 50%
#   - Installing scipy (1.13.1): Downloading... 30%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 50%
#   - Installing torchvision (0.17.2): Downloading... 70%
#   - Installing torchvision (0.17.2): Downloading... 90%
#   - Installing pandas (2.2.2): Downloading... 80%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 30%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 90%
#   - Installing matplotlib (3.9.0): Installing...
#   - Installing pandas (2.2.2): Downloading... 80%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 30%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 90%
#   - Installing torchvision (0.17.2): Downloading... 100%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 100%
#   - Installing scipy (1.13.1): Downloading... 40%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 100%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 40%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 100%
#   - Installing pandas (2.2.2): Downloading... 100%
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 40%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Downloading... 100%
#   - Installing torchvision (0.17.2): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing scipy (1.13.1): Downloading... 50%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 50%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing pandas (2.2.2): Installing...
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 50%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing scipy (1.13.1): Downloading... 60%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing scipy (1.13.1): Downloading... 70%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing scipy (1.13.1): Downloading... 80%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing scipy (1.13.1): Downloading... 90%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2): Installing...
#   - Installing torchvision (0.17.2)
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing scipy (1.13.1): Downloading... 100%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing pandas (2.2.2): Installing...
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 100%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing matplotlib (3.9.0)
#   - Installing pandas (2.2.2): Installing...
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Downloading... 100%
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing scipy (1.13.1): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing pandas (2.2.2)
#   - Installing safetensors (0.4.3)
#   - Installing scipy (1.13.1): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing scipy (1.13.1)
#   - Installing threadpoolctl (3.5.0)
#   - Installing torchvision (0.17.2)
#   - Installing scikit-learn (1.5.0): Pending...
#   - Installing seaborn (0.13.2): Pending...
#   - Installing timm (0.9.16): Pending...
#   - Installing seaborn (0.13.2): Pending...
#   - Installing timm (0.9.16): Pending...
#   - Installing scikit-learn (1.5.0): Downloading... 0%
#   - Installing seaborn (0.13.2): Pending...
#   - Installing timm (0.9.16): Pending...
#   - Installing timm (0.9.16): Pending...
#   - Installing seaborn (0.13.2): Downloading... 0%
#   - Installing timm (0.9.16): Pending...
#   - Installing timm (0.9.16): Downloading... 0%
#   - Installing timm (0.9.16): Downloading... 0%
#   - Installing seaborn (0.13.2): Downloading... 100%
#   - Installing timm (0.9.16): Downloading... 0%
#   - Installing timm (0.9.16): Downloading... 0%
#   - Installing seaborn (0.13.2): Installing...
#   - Installing timm (0.9.16): Downloading... 0%
#   - Installing timm (0.9.16): Downloading... 0%
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Downloading... 0%
#   - Installing timm (0.9.16): Downloading... 70%
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Downloading... 70%
#   - Installing scikit-learn (1.5.0): Downloading... 20%
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Downloading... 70%
#   - Installing timm (0.9.16): Downloading... 100%
#   - Installing timm (0.9.16): Installing...
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Installing...
#   - Installing scikit-learn (1.5.0): Downloading... 50%
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Installing...
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Installing...
#   - Installing scikit-learn (1.5.0): Downloading... 80%
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Installing...
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Installing...
#   - Installing scikit-learn (1.5.0): Downloading... 100%
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16): Installing...
#   - Installing timm (0.9.16)
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16)
#   - Installing scikit-learn (1.5.0): Installing...
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16)
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16)
#   - Installing scikit-learn (1.5.0)
#   - Installing seaborn (0.13.2)
#   - Installing timm (0.9.16)
#
# Installing the current project: pytorch-use-cases (0.1.0)
# Warning: The current project could not be installed: No file/folder found for package pytorch-use-cases
# If you do not want to install the current project use --no-root.
# If you want to use Poetry only for dependency management but not for packaging, you can disable package mode by setting package-mode = false in your pyproject.toml file.
# In a future version of Poetry this warning will become an error!

# %%
# !pip install timm
# Out:
# Collecting timm
#   Downloading timm-1.0.7-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.18.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.23.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->timm)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->timm)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->timm)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->timm)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->timm)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->timm)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->timm)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->timm)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->timm)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->timm)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->timm)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->timm)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, timm
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 timm-1.0.7

# %%
# %cd  computer_vision/image_classification
# Out:
# /content/PyTorch-Use-Cases/computer_vision/image_classification
